# %% [markdown]
# #Linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# #Data

# %%
np.random.seed(42)
X_experience = np.random.rand(100, 1) * 10 # 100 samples ranging from 1 to 10
print(X_experience.shape)
y_salary = 30000 + 7500 * X_experience.squeeze() + np.random.normal(0, 5000, 100)
df_salary = pd.DataFrame({'Years Experience': X_experience.squeeze(), 'Salary': y_salary})
print("Salary Dataset Head:")
print(df_salary.head())
df_salary.describe()
plt.scatter(X_experience, y_salary)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.show()
plt.hist(y_salary, bins=20)
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Distribution of Salaries')
plt.show()
# Out:
# (100, 1)
# Salary Dataset Head:
#    Years Experience        Salary
# 0          3.745401  58525.744255
# 1          9.507143  99808.536228
# 2          7.319939  85358.349519
# 3          5.986585  64961.541742
# 4          1.560186  40603.038594

# %%
from sklearn.model_selection import train_test_split

X = df_salary[['Years Experience']]
y = df_salary[['Salary']]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=46, shuffle=True)
print(f"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (70, 1), X_test shape: (30, 1)
# y_train shape: (70, 1), y_test shape: (30, 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred_test = model.predict(X_test_scaled)
print("\nPredictions on the test set (first 5):")
for actual, pred in list(zip(y_test, y_pred_test))[:5]:
    print(f"Actual: {actual:}, Predicted: {pred:}")
# Out:
# Predictions on the test set (first 5):
# Actual: Salary, Predicted: [44884.61145015]
